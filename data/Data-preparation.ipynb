# %% [markdown]
# <a href="https://colab.research.google.com/github/hungpham13/Distributed-data-discretization/blob/main/Data-preparation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import pyspark
# from pyspark.sql import SparkSession
# from pyspark.sql.types import StructType,StructField, StringType, IntegerType 
# from pyspark.sql.types import ArrayType, DoubleType, BooleanType
# from pyspark.sql.functions import col,array_contains

import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df2021 = pd.read_csv('diemthi2021.csv')
df2021['D1'].dropna().sample(n = 10000, random_state=1, ignore_index=True)
# Out:
# 0       14.45
# 1       23.40
# 2       25.00
# 3       21.25
# 4       13.80
#         ...
# 9995    22.75
# 9996    21.25
# 9997    19.45
# 9998    25.55
# 9999    21.80
# Name: D1, Length: 10000, dtype: float64

# %%
sns.histplot(df2021['D1'].dropna().sample(n = 10000, ignore_index=True), binwidth=0.5)
# Out:
# <AxesSubplot:xlabel='D1', ylabel='Count'>

# %%
sns.histplot(df2021['D1'].dropna(), binwidth=0.5)
# Out:
# <AxesSubplot:xlabel='D1', ylabel='Count'>

# %%
def data_create(num_sample = 10000, num_row = 450, year = 2021):
    data = []
    df = pd.read_csv('diemthi'+str(year)+'.csv')

    for i in range(num_row):
        data.append(list(df['D1'].dropna().sample(n = num_sample, ignore_index=True)))
        
    return np.array(data)

# %%
data2021 = data_create(num_row=630)

# %%
data2021.shape
# Out:
# (630, 10000)

# %%
data2021
# Out:
# array([[15.6 , 23.5 , 19.5 , ..., 12.2 , 14.25, 12.7 ],
#        [19.6 , 16.15, 21.6 , ..., 12.2 , 15.85, 15.95],
#        [21.8 , 24.95, 16.85, ..., 20.85, 16.85, 19.55],
#        ...,
#        [19.5 , 17.6 , 22.15, ..., 27.1 , 16.05, 13.3 ],
#        [18.25, 13.4 ,  8.05, ..., 20.2 , 19.05, 23.05],
#        [16.95, 14.55, 21.1 , ..., 19.25, 25.75, 17.85]])

# %%
# pd.DataFrame(data2021).to_csv('2021D1.csv')

# %%
data2018 = data_create(num_row = 30, year = 2018)
data2019 = data_create(num_row = 20, year = 2019)
data2020 = data_create(num_row = 20, year = 2020)

data_other = np.append(data2018, data2019, axis=0)
data_other = np.append(data_other, data2020, axis=0)
data_other
# Out:
# array([[13.05, 18.35, 19.65, ..., 17.3 , 12.65, 15.75],
#        [11.75, 13.2 , 10.55, ..., 18.85, 19.85, 13.2 ],
#        [16.2 , 13.35, 14.5 , ..., 12.95, 20.9 ,  6.8 ],
#        ...,
#        [12.1 , 16.  , 15.6 , ..., 22.55, 19.3 , 19.85],
#        [20.6 , 21.9 , 20.  , ..., 18.05, 22.75, 15.75],
#        [20.8 , 13.05, 20.65, ..., 17.25,  6.  , 15.7 ]])

# %%
# pd.DataFrame(data_other).to_csv('OtherD1.csv')

# %%
df2018 = pd.read_csv('diemthi2018.csv')
df2019 = pd.read_csv('diemthi2019.csv')
df2020 = pd.read_csv('diemthi2020.csv')

# %%
sns.histplot(df2020['D1'].dropna(), binwidth=0.5)
plt.show()

sns.histplot(data2020[0], binwidth=0.5)
plt.show()

# %%
sns.histplot(df2019['D1'].dropna(), binwidth=0.5)
plt.show()

sns.histplot(data2019[0], binwidth=0.5)
plt.show()

# %%
sns.histplot(df2018['D1'].dropna(), binwidth=0.5)
plt.show()

sns.histplot(data2018[0], binwidth=0.5)
plt.show()

# %%
sns.kdeplot(data = df2018, x = 'D1')
sns.kdeplot(data = df2019, x = 'D1')
sns.kdeplot(data = df2020, x = 'D1')
sns.kdeplot(data = df2021, x = 'D1')
# Out:
# <AxesSubplot:xlabel='D1', ylabel='Density'>

# %%
sns.kdeplot(data2021[0])
sns.kdeplot(data2021[1])
sns.kdeplot(data2021[2])
sns.kdeplot(data2021[100])
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.kdeplot(data = df2018, x = 'D1')
sns.kdeplot(data = df2019, x = 'D1')
sns.kdeplot(data = df2020, x = 'D1')
sns.kdeplot(data = df2021, x = 'D1')

# %%
sns.kdeplot(data2021[0])
sns.kdeplot(data2021[1])
sns.kdeplot(data2021[2])
sns.kdeplot(data2021[100])

# %%
from data.gen_data import generate_data
train, test = generate_data(num_train=500, num_test=200, true_ratio=0.9, visualize=True, num_sample=10000, bin_num=5)
train
# Out:
# Config: [(0.8011333656941132, 0.46489020141663784), (0.5940910812956512, 0.2638342685919366), (0.14672214611788026, 0.42570062662047586), (0.950856007867469, 0.4968164039446991), (0.6720842859463928, 0.21043364501560846)]
#             0         1         2         3         4         5         6  \
# 0    1.528012  0.433072  0.451402  1.098722  0.265512  1.614318  0.900622
# 1    1.173446  1.278939  1.414594  0.690885  1.491399  0.492147  0.512670
# 2    1.302929  1.075084  0.841804  0.182235  0.622387  1.191039  1.375231
# 3   -0.087007  0.628732  1.286408  0.593496  0.332447  0.503692  0.934778
# 4    0.775209  0.251772  0.452600  0.747279  1.249691  0.265729  1.033630
# ..        ...       ...       ...       ...       ...       ...       ...
# 495  1.001917  0.994059  1.453067  1.141250  1.200028  0.948198  0.595662
# 496 -0.682796  1.436357  0.102500  1.079783  0.066206  0.983853  0.451456
# 497  0.976681  0.152744  0.389971  0.776808  0.833047  1.356175  0.179281
# 498  1.175541  1.564170  1.356643  0.736340  0.887034  0.857637  1.529854
# 499  1.070165  1.111677  0.390278  1.098759  0.742296 -0.176181  1.029667
#
#             7         8         9  ...      9991      9992      9993  \
# 0    0.041487  0.757183  1.290937  ...  0.887633  1.036355  0.578993
# 1   -0.003579  1.145175  0.708372  ...  0.772177  0.632304  0.468866
# 2    0.666223  1.497239  0.783877  ...  0.464968  0.475715  0.675359
# 3    0.523211  0.188729  0.853717  ...  0.420136  0.496653  0.477510
# 4    1.417897  0.363022  0.457158  ...  0.255198  0.392585  0.471154
# ..        ...       ...       ...  ...       ...       ...       ...
# 495  0.980833  0.089296  1.402800  ...  0.066957  0.874569  0.278505
# 496  0.116872  0.542970  0.503135  ... -0.113193 -0.305461  0.412934
# 497 -0.020528  0.531432  1.682539  ...  0.487924  0.397577  0.808648
# 498 -0.142017  1.038364  1.217498  ...  0.519805  0.915623  0.921588
# 499  0.919235  0.603393  0.062110  ...  0.384019  1.062270  1.112131
#
#          9994      9995      9996      9997      9998      9999  Label
# 0    0.391090  1.093494  0.519962  0.758768  0.469736  0.769989      0
# 1    0.958213  0.375496  0.886716  0.905746  0.985972  0.488241      0
# 2    0.603553  1.056962  0.445754  0.589994  0.634686  0.354236      0
# 3    0.803812  0.580552  0.639485  0.634116  0.730026  0.738395      0
# 4    0.909351  0.775653  0.799512  0.651084  0.853207  0.452101      0
# ..        ...       ...       ...       ...       ...       ...    ...
# 495  0.122404  0.391527  0.392411  0.498955  0.899541 -0.195409      1
# 496  0.530416  0.641561  0.323793  0.744872  0.283770  0.769644      1
# 497  0.598150  0.671134  0.577396  0.961565  0.834993  0.530849      0
# 498  0.513016  0.635305  0.679433  0.670256  0.839662  0.281093      0
# 499  0.605952  0.872487  0.641440  1.189336  0.905359  0.785294      0
#
# [500 rows x 10001 columns]
