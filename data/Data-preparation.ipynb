# %% [markdown]
# <a href="https://colab.research.google.com/github/hungpham13/Distributed-data-discretization/blob/main/Data-preparation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import pyspark
# from pyspark.sql import SparkSession
# from pyspark.sql.types import StructType,StructField, StringType, IntegerType 
# from pyspark.sql.types import ArrayType, DoubleType, BooleanType
# from pyspark.sql.functions import col,array_contains

import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df2021 = pd.read_csv('diemthi2021.csv')
df2021['D1'].dropna().sample(n = 10000, random_state=1, ignore_index=True)
# Out:
# 0       14.45
# 1       23.40
# 2       25.00
# 3       21.25
# 4       13.80
#         ...
# 9995    22.75
# 9996    21.25
# 9997    19.45
# 9998    25.55
# 9999    21.80
# Name: D1, Length: 10000, dtype: float64

# %%
sns.histplot(df2021['D1'].dropna().sample(n = 10000, ignore_index=True), binwidth=0.5)
# Out:
# <AxesSubplot:xlabel='D1', ylabel='Count'>

# %%
sns.histplot(df2021['D1'].dropna(), binwidth=0.5)
# Out:
# <AxesSubplot:xlabel='D1', ylabel='Count'>

# %%
def data_create(num_sample = 10000, num_row = 450, year = 2021):
    data = []
    df = pd.read_csv('diemthi'+str(year)+'.csv')

    for i in range(num_row):
        data.append(list(df['D1'].dropna().sample(n = num_sample, ignore_index=True)))
        
    return np.array(data)

# %%
data2021 = data_create(num_row=630)

# %%
data2021.shape
# Out:
# (630, 10000)

# %%
data2021
# Out:
# array([[15.6 , 23.5 , 19.5 , ..., 12.2 , 14.25, 12.7 ],
#        [19.6 , 16.15, 21.6 , ..., 12.2 , 15.85, 15.95],
#        [21.8 , 24.95, 16.85, ..., 20.85, 16.85, 19.55],
#        ...,
#        [19.5 , 17.6 , 22.15, ..., 27.1 , 16.05, 13.3 ],
#        [18.25, 13.4 ,  8.05, ..., 20.2 , 19.05, 23.05],
#        [16.95, 14.55, 21.1 , ..., 19.25, 25.75, 17.85]])

# %%
# pd.DataFrame(data2021).to_csv('2021D1.csv')

# %%
data2018 = data_create(num_row = 30, year = 2018)
data2019 = data_create(num_row = 20, year = 2019)
data2020 = data_create(num_row = 20, year = 2020)

data_other = np.append(data2018, data2019, axis=0)
data_other = np.append(data_other, data2020, axis=0)
data_other
# Out:
# array([[13.05, 18.35, 19.65, ..., 17.3 , 12.65, 15.75],
#        [11.75, 13.2 , 10.55, ..., 18.85, 19.85, 13.2 ],
#        [16.2 , 13.35, 14.5 , ..., 12.95, 20.9 ,  6.8 ],
#        ...,
#        [12.1 , 16.  , 15.6 , ..., 22.55, 19.3 , 19.85],
#        [20.6 , 21.9 , 20.  , ..., 18.05, 22.75, 15.75],
#        [20.8 , 13.05, 20.65, ..., 17.25,  6.  , 15.7 ]])

# %%
# pd.DataFrame(data_other).to_csv('OtherD1.csv')

# %%
df2018 = pd.read_csv('diemthi2018.csv')
df2019 = pd.read_csv('diemthi2019.csv')
df2020 = pd.read_csv('diemthi2020.csv')

# %%
sns.histplot(df2020['D1'].dropna(), binwidth=0.5)
plt.show()

sns.histplot(data2020[0], binwidth=0.5)
plt.show()

# %%
sns.histplot(df2019['D1'].dropna(), binwidth=0.5)
plt.show()

sns.histplot(data2019[0], binwidth=0.5)
plt.show()

# %%
sns.histplot(df2018['D1'].dropna(), binwidth=0.5)
plt.show()

sns.histplot(data2018[0], binwidth=0.5)
plt.show()

# %%
sns.kdeplot(data = df2018, x = 'D1')
sns.kdeplot(data = df2019, x = 'D1')
sns.kdeplot(data = df2020, x = 'D1')
sns.kdeplot(data = df2021, x = 'D1')
# Out:
# <AxesSubplot:xlabel='D1', ylabel='Density'>

# %%
sns.kdeplot(data2021[0])
sns.kdeplot(data2021[1])
sns.kdeplot(data2021[2])
sns.kdeplot(data2021[100])
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.kdeplot(data = df2018, x = 'D1')
sns.kdeplot(data = df2019, x = 'D1')
sns.kdeplot(data = df2020, x = 'D1')
sns.kdeplot(data = df2021, x = 'D1')

# %%
sns.kdeplot(data2021[0])
sns.kdeplot(data2021[1])
sns.kdeplot(data2021[2])
sns.kdeplot(data2021[100])

# %%
from data.gen_data import generate_data
train, test = generate_data(num_train=500, num_test=200, true_ratio=0.9, visualize=True, num_sample=10000, bin_num=5)
train
# Out:
# Config: [(0.1518480400497123, 0.27124725172601927), (0.608806330935566, 0.32206756593783087), (0.03191949442993636, 0.4244363874962457), (0.40765038038423485, 0.12482386671778217), (0.044965809602608875, 0.29539578953410045)]
#             0         1         2         3         4         5         6  \
# 0   -0.151126  0.329368 -0.005166  0.312553  0.299649  0.244246 -0.141197
# 1    0.044522  0.433354  0.293473  0.108131  0.102804  0.512193 -0.182562
# 2    0.859686  0.204480  0.354260  0.088890  0.177604 -0.046845  0.054319
# 3    0.946443  0.435495 -0.114724 -0.057723  0.494608  0.058191  0.154529
# 4    0.580072  0.244361 -0.089421 -0.089269 -0.442264 -0.037719  0.494547
# ..        ...       ...       ...       ...       ...       ...       ...
# 495 -0.138118  0.445180  0.183967 -0.112455  0.459346 -0.068450  0.568633
# 496 -0.004376 -0.085653  0.494762  0.392557  0.251219  0.014990 -0.280953
# 497 -0.092871  0.172613  0.461731 -0.002759  0.464917  0.436578  0.871570
# 498  0.324934 -0.034549 -0.335081  0.058867  0.098745  0.005920  0.248240
# 499 -0.037930  0.357090 -0.425356  0.201579  0.253844  0.333417 -0.109648
#
#             7         8         9  ...      9991      9992      9993  \
# 0   -0.393680  0.235464  0.365376  ...  0.279161  0.582668  0.235083
# 1    0.064443  0.564087  0.023589  ...  0.055886 -0.103276 -0.000154
# 2    0.642918  0.102790  0.194818  ...  0.398932 -0.326895 -0.113255
# 3    0.657538  0.169777  0.396704  ...  0.222674  0.018589 -0.691796
# 4    0.006527 -0.172850 -0.506578  ... -0.155751 -0.255739  0.081441
# ..        ...       ...       ...  ...       ...       ...       ...
# 495  0.275945 -0.132595  0.064300  ... -0.087809  0.602624 -0.261825
# 496  0.226922  0.314587  0.031983  ... -0.267692 -0.167908 -0.216761
# 497  0.236689  0.086761  0.267988  ...  0.007928 -0.084797  0.535317
# 498 -0.027489  0.027699  0.493745  ... -0.019572 -0.048663  0.498570
# 499  0.019629 -0.072385  0.064474  ... -0.221822 -0.513680  0.002507
#
#          9994      9995      9996      9997      9998      9999  Label
# 0   -0.115176 -0.338933  0.108723 -0.098103  0.148189  0.300051      0
# 1    0.262166 -0.782836  0.378191 -0.553797  0.059107  0.368290      0
# 2   -0.068809 -0.077214  0.007240 -0.097044  0.332889  0.607499      0
# 3   -0.456669  0.112550 -0.719703  0.064331  0.207343 -0.418183      0
# 4    0.261143  0.325464  0.195036  0.057234  0.738467  0.743352      0
# ..        ...       ...       ...       ...       ...       ...    ...
# 495 -0.138783 -0.104681  0.034422  0.079473  0.211797  0.180360      0
# 496  0.094027 -0.483534  0.002047  0.041221 -0.458098  0.257787      0
# 497 -0.030539 -0.372360  0.090485 -0.389581  0.311093  0.502370      0
# 498 -0.139619 -0.136098  0.208814 -0.032456 -0.087941  0.203728      0
# 499  0.165315 -0.427519 -0.129997 -0.201270 -0.041180  0.281958      0
#
# [500 rows x 10001 columns]
